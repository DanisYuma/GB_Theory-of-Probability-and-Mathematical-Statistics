# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# Постройте графики для приведенных наборов данных. Найдите коэффициенты для линии регрессии и коэффициенты детерминации. Что вы замечаете? Нанесите на график модель линейной регрессии.

# %%
x1 = np.array([30, 30, 40, 40])
y1 = np.array([37, 47, 50, 60])

x2 = np.array([30, 30, 40, 40, 20, 20, 50, 50])
y2 = np.array([37, 47, 50, 60, 25, 35, 62, 72])

x3 = np.array([30,30,40, 40, 20, 20, 50, 50, 10, 10, 60, 60])
y3 = np.array([37, 47, 50, 60, 25, 35, 62, 72, 13, 23, 74, 84])

# %%
plt.scatter(x1, y1)
plt.xlabel('X1')
plt.ylabel('X1')
plt.show()

# %%
plt.scatter(x2, y2)
plt.xlabel('X2')
plt.ylabel('X2')
plt.show()

# %%
plt.scatter(x3, y3)
plt.xlabel('X3')
plt.ylabel('X3')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
x1 = x1.reshape(-1, 1)

model = LinearRegression()
model.fit(x1, y1)
r_sq = model.score(x1, y1)

print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.6282527881040892
# intercept: 3.0
# slope: [1.3]

# %%
plt.scatter(x1, y1)
plt.plot(x1,3+1.3*x1)
plt.show()

# %%
model = LinearRegression()
x2 = x2.reshape(-1, 1)
model.fit(x2, y2)
r_sq = model.score(x2, y2)

print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.8846950517836594
# intercept: 5.1000000000000085
# slope: [1.24]

# %%
plt.scatter(x2, y2)
plt.plot(x2,5.1+1.24*x2)
plt.show()

# %%
model = LinearRegression()
x3 = x3.reshape(-1, 1)
model.fit(x3, y3)
r_sq = model.score(x3, y3)

print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.9459101071621309
# intercept: 5.600000000000016
# slope: [1.22571429]

# %%
plt.scatter(x3, y3)
plt.plot(x3,5.6+1.23*x3)
plt.show()

# %% [markdown]
# На 8 уроке мы строили графики приведенных ниже данных.
# Для какого графика можно использовать модель линейной регрессии?
# x = np.array([10,8, 13, 9,11,14, 6,4,12, 7,5])
# y = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68 ])

# %%
x22 = np.array([10,8, 13, 9,11,14, 6,4,12, 7,5])
y22 = np.array([8.04, 6.95, 7.58, 8.81, 8.33, 9.96, 7.24, 4.26, 10.84, 4.82, 5.68 ])

# %%
plt.scatter(x22,y22)
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
model = LinearRegression()
x22 = x22.reshape(-1, 1)
model.fit(x22, y22)
r_sq = model.score(x22, y22)

print('coefficient of determination:', r_sq)
print('intercept:', model.intercept_)
print('slope:', model.coef_)
# Out:
# coefficient of determination: 0.6665424595087748
# intercept: 3.0000909090909094
# slope: [0.50009091]

# %%
plt.scatter(x22, y22)
plt.plot(x22, 3+0.5*x22)
plt.show()

# %%
y_ost = 3 + 0.5 * x22
y_ostr = y_ost.reshape(1,-1)
y_ost, y_ostr
# Out:
# (array([[ 8. ],
#         [ 7. ],
#         [ 9.5],
#         [ 7.5],
#         [ 8.5],
#         [10. ],
#         [ 6. ],
#         [ 5. ],
#         [ 9. ],
#         [ 6.5],
#         [ 5.5]]),
#  array([[ 8. ,  7. ,  9.5,  7.5,  8.5, 10. ,  6. ,  5. ,  9. ,  6.5,  5.5]]))

# %%
res = y22 - y_ostr
res
# Out:
# array([[ 0.04, -0.05, -1.92,  1.31, -0.17, -0.04,  1.24, -0.74,  1.84,
#         -1.68,  0.18]])

# %%
plt.scatter(x22, res)
plt.show()

# %%
stats.shapiro(res)
# Out:
# ShapiroResult(statistic=0.9420998096466064, pvalue=0.545490026473999)

# %%
plt.scatter(y_ost, res)
plt.show()

# %%
t = stats.f.ppf(0.95, 1, 9)
t
# Out:
# 5.117355029199227

# %%
y_pred = model.predict(x22)
y_pred
# Out:
# array([ 8.001     ,  7.00081818,  9.50127273,  7.50090909,  8.50109091,
#        10.00136364,  6.00063636,  5.00045455,  9.00118182,  6.50072727,
#         5.50054545])

# %%
SSf = sum((y_pred - np.mean(y22))**2)
SSo = np.sum((y22 - y_pred)**2)
df1 = 2 - 1
df2 = 11 - 2
Msf = SSf / df1
Mso = SSo / df2
F = Msf/Mso
F
# Out:
# 17.989942967676978
