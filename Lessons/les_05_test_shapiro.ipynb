# %%
import numpy as np
import scipy.stats as stats
import pylab
import matplotlib.pylab as plt

# %%
s = np.random.normal(0, 1, 50)
s
# Out:
# array([-1.30798606,  1.37335091, -0.42343003, -1.66515   ,  0.04267285,
#        -0.35102531, -0.7575315 , -0.2249596 , -0.38249627, -0.41192348,
#         1.97383408, -0.8739072 , -0.42657166,  1.46215171, -0.36993692,
#         0.61515309,  0.51760543, -1.18176863,  0.18475069,  0.97600902,
#        -0.58578672, -1.61961491, -1.55971914, -0.27451736,  0.45107542,
#         1.30782768,  0.00603834,  0.55528742, -0.41627743,  0.02437618,
#         0.18409188,  1.16716053, -2.05486386,  1.86564313,  0.40520004,
#        -0.66132542,  0.37401303, -0.11081298, -0.25658556, -1.32398504,
#         0.69161292, -0.55676152,  0.03415181,  1.26986829,  0.97805896,
#        -2.46584171,  0.73290904,  1.95001499,  0.58842469, -2.01823585])

# %%
stats.shapiro(s)
# Out:
# ShapiroResult(statistic=0.9836245775222778, pvalue=0.7112510204315186)

# %%
stats.probplot(s, dist= "norm", plot= plt)
plt.show()
